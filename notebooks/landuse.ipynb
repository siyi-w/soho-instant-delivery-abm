# %%
import osmnx as ox

center = (51.51350000000001, -0.1365)

gdf = ox.features_from_point(
    center, dist=1900,
    tags={"landuse": True}
)
gdf.to_file("/Users/wusiyi/Documents/CASA/dis/DATA/raw/osm_landuse_r1900.geojson", driver="GeoJSON")
print(len(gdf), "个 land use 要素")
print(gdf["landuse"].value_counts())
# Out:
# 1180 个 land use 要素
# landuse
# grass                      303
# retail                     231
# residential                229
# commercial                 129
# flowerbed                  115
# construction                54
# railway                     23
# hospitality                 21
# recreation_ground           13
# religious                   13
# industrial                  10
# military                    10
# brownfield                   7
# allotments                   5
# governmental                 5
# forest                       3
# cemetery                     2
# education                    2
# village_green                1
# churchyard                   1
# farmyard                     1
# plant_nursery                1
# greenhouse_horticulture      1
# Name: count, dtype: int64
